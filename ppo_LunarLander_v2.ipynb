# %% [markdown]
# <a href="https://colab.research.google.com/github/amitdamri/HuggingFace-DRL/blob/main/ppo_LunarLander_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Downloads

# %%
# !apt install swig cmake

# %%
# !pip install -r https://huggingface.co/spaces/ThomasSimonini/temp-space-requirements/raw/main/requirements/requirements-unit1.txt

# %%
# !sudo apt-get update
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# !pip install importlib-metadata==4.12.0 # To overcome an issue with importlib-metadata https://stackoverflow.com/questions/73929564/entrypoints-object-has-no-attribute-get-digital-ocean
# !pip install gym[box2d]
# !pip install gym[Atari]
# !pip install stable-baselines3[extra]
# !pip install huggingface_sb3
# !pip install pyglet
# !pip install ale-py==0.7.4 # To overcome an issue with gym (https://github.com/DLR-RM/stable-baselines3/issues/875)

# !pip install pickle5

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# !pip install imageio==2.4.1

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display
virtual_display = Display(visible = 0, size = (1400, 900))
virtual_display.start()

# %%
import gym

from huggingface_hub import notebook_login
from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %% [markdown]
# # PPO

# %% [markdown]
# ### Train the PPO model

# %%
# create environment
env = make_vec_env('LunarLander-v2', n_envs = 16)

# Create PPO model
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)

# Train the model
model.learn(total_timesteps=1e6, progress_bar = True)
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Using cuda device
# Output()
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/callbacks.py:680: TqdmExperimentalWarning: rich is experimental/alpha
#   self.pbar = tqdm(total=self.locals["total_timesteps"] - self.model.num_timesteps)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.3     |
# |    ep_rew_mean     | -172     |
# | time/              |          |
# |    fps             | 2105     |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.8         |
# |    ep_rew_mean          | -147         |
# | time/                   |              |
# |    fps                  | 1713         |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053383047 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00102      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00596     |
# |    value_loss           | 5.13e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.8        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 1625        |
# |    iterations           | 3           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007789383 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00859    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.1        |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 1611        |
# |    iterations           | 4           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011308917 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0027     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 412         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 958         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 106        |
# |    ep_rew_mean          | -96.2      |
# | time/                   |            |
# |    fps                  | 1599       |
# |    iterations           | 5          |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00812315 |
# |    clip_fraction        | 0.0478     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | -0.000323  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 274        |
# |    n_updates            | 16         |
# |    policy_gradient_loss | -0.00334   |
# |    value_loss           | 609        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -85.2       |
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 6           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009410192 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.000414   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 276         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 585         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -64.7       |
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 7           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.007333111 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.000463    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 482         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 532         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | -50.1       |
# | time/                   |             |
# |    fps                  | 1565        |
# |    iterations           | 8           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009337972 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.139      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 203         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 352         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | -22.7       |
# | time/                   |             |
# |    fps                  | 1549        |
# |    iterations           | 9           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.007917609 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -3.87e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 149         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 363         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | -17.5        |
# | time/                   |              |
# |    fps                  | 1463         |
# |    iterations           | 10           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0044455677 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -2.32e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 194          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 493          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | -11.4        |
# | time/                   |              |
# |    fps                  | 1386         |
# |    iterations           | 11           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0079442365 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -7.27e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 463          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 513          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | -4.52       |
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 12          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008722959 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 214         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00146    |
# |    value_loss           | 581         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | -8.29       |
# | time/                   |             |
# |    fps                  | 1219        |
# |    iterations           | 13          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.007939704 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 1.57e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 489         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | -7           |
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 14           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0034774612 |
# |    clip_fraction        | 0.00343      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 125          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 434          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 343         |
# |    ep_rew_mean          | -1.46       |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 15          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.007377644 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 156         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 343         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | 3.9         |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 16          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.004954774 |
# |    clip_fraction        | 0.0246      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 242         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 508          |
# |    ep_rew_mean          | 3.46         |
# | time/                   |              |
# |    fps                  | 998          |
# |    iterations           | 17           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0048811436 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.3         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 195          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 596         |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 18          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008145565 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 177         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 684         |
# |    ep_rew_mean          | 24.4        |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 19          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.004758928 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.8        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 164         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | 33.5         |
# | time/                   |              |
# |    fps                  | 899          |
# |    iterations           | 20           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0073177777 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.9         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 70.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 21          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.005363644 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 743         |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 22          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.006154871 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 77.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 60.9         |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 23           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0055282013 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.8         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 203          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 775          |
# |    ep_rew_mean          | 65.6         |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 24           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0052691307 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.6         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000537    |
# |    value_loss           | 86           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 778         |
# |    ep_rew_mean          | 60.6        |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 25          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.003579036 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 81.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 794          |
# |    ep_rew_mean          | 64.4         |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 26           |
# |    time_elapsed         | 528          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0039745816 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 86.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 814          |
# |    ep_rew_mean          | 75.7         |
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 27           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0045442665 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 50.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 805          |
# |    ep_rew_mean          | 70.4         |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 28           |
# |    time_elapsed         | 582          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0051052356 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.829        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.9         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 839         |
# |    ep_rew_mean          | 75.2        |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 29          |
# |    time_elapsed         | 609         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004411371 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 69.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 875         |
# |    ep_rew_mean          | 91          |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 30          |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004333722 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.000658   |
# |    value_loss           | 35.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | 96.4        |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 31          |
# |    time_elapsed         | 665         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004777614 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.99        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -7.6e-05    |
# |    value_loss           | 30.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 99.6         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 32           |
# |    time_elapsed         | 691          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0033217648 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 29.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 898          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 752          |
# |    iterations           | 33           |
# |    time_elapsed         | 718          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0052860044 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000377    |
# |    value_loss           | 38           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 906         |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 34          |
# |    time_elapsed         | 745         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.003321258 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.000529   |
# |    value_loss           | 63.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 906          |
# |    ep_rew_mean          | 114          |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 35           |
# |    time_elapsed         | 772          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0054951627 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000803    |
# |    value_loss           | 20.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 36           |
# |    time_elapsed         | 799          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0042506494 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.98         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000318    |
# |    value_loss           | 36.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 935        |
# |    ep_rew_mean          | 124        |
# | time/                   |            |
# |    fps                  | 729        |
# |    iterations           | 37         |
# |    time_elapsed         | 831        |
# |    total_timesteps      | 606208     |
# | train/                  |            |
# |    approx_kl            | 0.00570454 |
# |    clip_fraction        | 0.0534     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.36       |
# |    n_updates            | 144        |
# |    policy_gradient_loss | -0.00191   |
# |    value_loss           | 10.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 957          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 38           |
# |    time_elapsed         | 859          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0038747506 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.67         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -2.7e-06     |
# |    value_loss           | 16.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 971         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 717         |
# |    iterations           | 39          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.007119526 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 6.25        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 978          |
# |    ep_rew_mean          | 135          |
# | time/                   |              |
# |    fps                  | 713          |
# |    iterations           | 40           |
# |    time_elapsed         | 918          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0061863507 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 4.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 978          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 41           |
# |    time_elapsed         | 947          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0058243144 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000605    |
# |    value_loss           | 3.44         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 42          |
# |    time_elapsed         | 972         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004306304 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 26          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 43          |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.010491256 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.000575   |
# |    value_loss           | 32.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 44           |
# |    time_elapsed         | 1020         |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0034312545 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.31         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -7.99e-05    |
# |    value_loss           | 14           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 902         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 45          |
# |    time_elapsed         | 1043        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.003981516 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41          |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000175   |
# |    value_loss           | 13.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 135          |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 46           |
# |    time_elapsed         | 1067         |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0036779358 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 80.9         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00098     |
# |    value_loss           | 59.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 901          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 47           |
# |    time_elapsed         | 1090         |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0038144053 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.907       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.43         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000238    |
# |    value_loss           | 35.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 894         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 48          |
# |    time_elapsed         | 1113        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.004282844 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.7        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | 9.39e-05    |
# |    value_loss           | 27.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 49           |
# |    time_elapsed         | 1140         |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0034681186 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.879       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34           |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 27.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 907         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 50          |
# |    time_elapsed         | 1165        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.003086999 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.874      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.000344   |
# |    value_loss           | 2.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 51           |
# |    time_elapsed         | 1187         |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0051348377 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 42           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 918          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 52           |
# |    time_elapsed         | 1210         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0035841689 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.1         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000418    |
# |    value_loss           | 71.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 53           |
# |    time_elapsed         | 1232         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0041659307 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.08         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 76.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 877          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 54           |
# |    time_elapsed         | 1254         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0033789068 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -6.82e-05    |
# |    value_loss           | 70.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 813          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 55           |
# |    time_elapsed         | 1275         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0070165917 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.9         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 89.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 751        |
# |    ep_rew_mean          | 186        |
# | time/                   |            |
# |    fps                  | 707        |
# |    iterations           | 56         |
# |    time_elapsed         | 1295       |
# |    total_timesteps      | 917504     |
# | train/                  |            |
# |    approx_kl            | 0.00508183 |
# |    clip_fraction        | 0.0713     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.691     |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 114        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00348   |
# |    value_loss           | 277        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 638         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 57          |
# |    time_elapsed         | 1316        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.003440517 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 224         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 290         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 58           |
# |    time_elapsed         | 1335         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0086987335 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 348          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 59          |
# |    time_elapsed         | 1352        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.005019585 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 269         |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 278         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 371          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 60           |
# |    time_elapsed         | 1369         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0034445035 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.2         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -4.34e-05    |
# |    value_loss           | 144          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 361         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 61          |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.004630944 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000837   |
# |    value_loss           | 221         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 62           |
# |    time_elapsed         | 1401         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0037659463 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.000813    |
# |    value_loss           | 175          |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ### Train PPO Model Optimized

# %%
from stable_baselines3.common.callbacks import EvalCallback

# create environment
n_envs = 16

env = make_vec_env('LunarLander-v2', n_envs = n_envs)

# Create the evaluation envs
eval_envs = make_vec_env('LunarLander-v2', n_envs=5)

# Adjust evaluation interval depending on the number of envs
eval_freq = int(1e5)
eval_freq = max(eval_freq // n_envs, 1)

# Create evaluation callback to save best model
# and monitor agent performance
eval_callback = EvalCallback(
    eval_envs,
    best_model_save_path="./logs/",
    eval_freq=eval_freq,
    n_eval_episodes=10,
)

# Create PPO model
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 8,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)

# Train the model
model.learn(total_timesteps=5e6, callback=eval_callback)
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Streaming output truncated to the last 5000 lines.
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 262          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 85           |
# |    time_elapsed         | 1726         |
# |    total_timesteps      | 1392640      |
# | train/                  |              |
# |    approx_kl            | 0.0049238214 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.667       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.974        |
# |    n_updates            | 672          |
# |    policy_gradient_loss | -0.000784    |
# |    value_loss           | 4.66         |
# ------------------------------------------
# Eval num_timesteps=1400000, episode_reward=278.76 +/- 20.06
# Episode length: 242.20 +/- 11.67
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 242         |
# |    mean_reward          | 279         |
# | time/                   |             |
# |    total_timesteps      | 1400000     |
# | train/                  |             |
# |    approx_kl            | 0.004811721 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.99        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.000809   |
# |    value_loss           | 6.26        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    fps             | 807      |
# |    iterations      | 86       |
# |    time_elapsed    | 1744     |
# |    total_timesteps | 1409024  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 87           |
# |    time_elapsed         | 1761         |
# |    total_timesteps      | 1425408      |
# | train/                  |              |
# |    approx_kl            | 0.0035655852 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.975        |
# |    n_updates            | 688          |
# |    policy_gradient_loss | 0.000258     |
# |    value_loss           | 2.68         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 88          |
# |    time_elapsed         | 1778        |
# |    total_timesteps      | 1441792     |
# | train/                  |             |
# |    approx_kl            | 0.003141524 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 696         |
# |    policy_gradient_loss | 0.000762    |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 89          |
# |    time_elapsed         | 1794        |
# |    total_timesteps      | 1458176     |
# | train/                  |             |
# |    approx_kl            | 0.004231983 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 160         |
# |    n_updates            | 704         |
# |    policy_gradient_loss | -0.000547   |
# |    value_loss           | 254         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 90           |
# |    time_elapsed         | 1812         |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0041836887 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.66        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 199          |
# |    n_updates            | 712          |
# |    policy_gradient_loss | 0.000355     |
# |    value_loss           | 150          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 91          |
# |    time_elapsed         | 1828        |
# |    total_timesteps      | 1490944     |
# | train/                  |             |
# |    approx_kl            | 0.004093185 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.000421   |
# |    value_loss           | 73.2        |
# -----------------------------------------
# Eval num_timesteps=1500000, episode_reward=278.71 +/- 22.69
# Episode length: 237.00 +/- 16.11
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 237          |
# |    mean_reward          | 279          |
# | time/                   |              |
# |    total_timesteps      | 1500000      |
# | train/                  |              |
# |    approx_kl            | 0.0039438624 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.661       |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 491          |
# |    n_updates            | 728          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 334          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 245      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    fps             | 816      |
# |    iterations      | 92       |
# |    time_elapsed    | 1846     |
# |    total_timesteps | 1507328  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 93           |
# |    time_elapsed         | 1864         |
# |    total_timesteps      | 1523712      |
# | train/                  |              |
# |    approx_kl            | 0.0051381923 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14           |
# |    n_updates            | 736          |
# |    policy_gradient_loss | 0.000268     |
# |    value_loss           | 126          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 94          |
# |    time_elapsed         | 1881        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.006331763 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62        |
# |    n_updates            | 744         |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 17.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 95          |
# |    time_elapsed         | 1897        |
# |    total_timesteps      | 1556480     |
# | train/                  |             |
# |    approx_kl            | 0.005707497 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.16        |
# |    n_updates            | 752         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 5.95        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 96           |
# |    time_elapsed         | 1915         |
# |    total_timesteps      | 1572864      |
# | train/                  |              |
# |    approx_kl            | 0.0039685396 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92         |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.000761    |
# |    value_loss           | 22           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 239          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 97           |
# |    time_elapsed         | 1931         |
# |    total_timesteps      | 1589248      |
# | train/                  |              |
# |    approx_kl            | 0.0034786598 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.29         |
# |    n_updates            | 768          |
# |    policy_gradient_loss | -0.000484    |
# |    value_loss           | 207          |
# ------------------------------------------
# Eval num_timesteps=1600000, episode_reward=292.55 +/- 18.24
# Episode length: 241.90 +/- 16.52
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 242          |
# |    mean_reward          | 293          |
# | time/                   |              |
# |    total_timesteps      | 1600000      |
# | train/                  |              |
# |    approx_kl            | 0.0054971385 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.625       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 776          |
# |    policy_gradient_loss | -0.000167    |
# |    value_loss           | 74.4         |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    fps             | 824      |
# |    iterations      | 98       |
# |    time_elapsed    | 1948     |
# |    total_timesteps | 1605632  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 99          |
# |    time_elapsed         | 1964        |
# |    total_timesteps      | 1622016     |
# | train/                  |             |
# |    approx_kl            | 0.003133901 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 784         |
# |    policy_gradient_loss | 0.000301    |
# |    value_loss           | 149         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 251          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 826          |
# |    iterations           | 100          |
# |    time_elapsed         | 1981         |
# |    total_timesteps      | 1638400      |
# | train/                  |              |
# |    approx_kl            | 0.0045510996 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 792          |
# |    policy_gradient_loss | -0.000376    |
# |    value_loss           | 145          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 257          |
# |    ep_rew_mean          | 272          |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 101          |
# |    time_elapsed         | 1998         |
# |    total_timesteps      | 1654784      |
# | train/                  |              |
# |    approx_kl            | 0.0049685994 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.000381    |
# |    value_loss           | 5.08         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 102         |
# |    time_elapsed         | 2014        |
# |    total_timesteps      | 1671168     |
# | train/                  |             |
# |    approx_kl            | 0.004215301 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 808         |
# |    policy_gradient_loss | -0.000912   |
# |    value_loss           | 185         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 103          |
# |    time_elapsed         | 2030         |
# |    total_timesteps      | 1687552      |
# | train/                  |              |
# |    approx_kl            | 0.0044775167 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.62        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 816          |
# |    policy_gradient_loss | 4.83e-05     |
# |    value_loss           | 86.1         |
# ------------------------------------------
# Eval num_timesteps=1700000, episode_reward=286.58 +/- 18.60
# Episode length: 229.10 +/- 10.75
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 229       |
# |    mean_reward          | 287       |
# | time/                   |           |
# |    total_timesteps      | 1700000   |
# | train/                  |           |
# |    approx_kl            | 0.0047918 |
# |    clip_fraction        | 0.0534    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.616    |
# |    explained_variance   | 0.995     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.16      |
# |    n_updates            | 824       |
# |    policy_gradient_loss | 0.000581  |
# |    value_loss           | 5.17      |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    fps             | 831      |
# |    iterations      | 104      |
# |    time_elapsed    | 2048     |
# |    total_timesteps | 1703936  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 105         |
# |    time_elapsed         | 2066        |
# |    total_timesteps      | 1720320     |
# | train/                  |             |
# |    approx_kl            | 0.003606347 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 832         |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 37.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 106         |
# |    time_elapsed         | 2083        |
# |    total_timesteps      | 1736704     |
# | train/                  |             |
# |    approx_kl            | 0.004177588 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.000568    |
# |    value_loss           | 93.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 249          |
# |    ep_rew_mean          | 265          |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 107          |
# |    time_elapsed         | 2100         |
# |    total_timesteps      | 1753088      |
# | train/                  |              |
# |    approx_kl            | 0.0048498143 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.643       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.8         |
# |    n_updates            | 848          |
# |    policy_gradient_loss | -0.000132    |
# |    value_loss           | 144          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 108          |
# |    time_elapsed         | 2116         |
# |    total_timesteps      | 1769472      |
# | train/                  |              |
# |    approx_kl            | 0.0052575907 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.47         |
# |    n_updates            | 856          |
# |    policy_gradient_loss | 6.56e-05     |
# |    value_loss           | 64.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 109         |
# |    time_elapsed         | 2132        |
# |    total_timesteps      | 1785856     |
# | train/                  |             |
# |    approx_kl            | 0.006582521 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73        |
# |    n_updates            | 864         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 7.8         |
# -----------------------------------------
# Eval num_timesteps=1800000, episode_reward=285.60 +/- 21.29
# Episode length: 233.80 +/- 10.50
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 234          |
# |    mean_reward          | 286          |
# | time/                   |              |
# |    total_timesteps      | 1800000      |
# | train/                  |              |
# |    approx_kl            | 0.0038580548 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.621       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76         |
# |    n_updates            | 872          |
# |    policy_gradient_loss | -0.000136    |
# |    value_loss           | 65.5         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 241      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    fps             | 837      |
# |    iterations      | 110      |
# |    time_elapsed    | 2151     |
# |    total_timesteps | 1802240  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 111         |
# |    time_elapsed         | 2167        |
# |    total_timesteps      | 1818624     |
# | train/                  |             |
# |    approx_kl            | 0.004767238 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 79          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 231       |
# |    ep_rew_mean          | 280       |
# | time/                   |           |
# |    fps                  | 840       |
# |    iterations           | 112       |
# |    time_elapsed         | 2184      |
# |    total_timesteps      | 1835008   |
# | train/                  |           |
# |    approx_kl            | 0.0038611 |
# |    clip_fraction        | 0.0482    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.635    |
# |    explained_variance   | 0.975     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.9       |
# |    n_updates            | 888       |
# |    policy_gradient_loss | 0.000256  |
# |    value_loss           | 77.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 113         |
# |    time_elapsed         | 2200        |
# |    total_timesteps      | 1851392     |
# | train/                  |             |
# |    approx_kl            | 0.004320375 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 896         |
# |    policy_gradient_loss | -0.000935   |
# |    value_loss           | 72.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | 272          |
# | time/                   |              |
# |    fps                  | 842          |
# |    iterations           | 114          |
# |    time_elapsed         | 2217         |
# |    total_timesteps      | 1867776      |
# | train/                  |              |
# |    approx_kl            | 0.0046615475 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.627       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99         |
# |    n_updates            | 904          |
# |    policy_gradient_loss | -0.000965    |
# |    value_loss           | 66.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 115         |
# |    time_elapsed         | 2233        |
# |    total_timesteps      | 1884160     |
# | train/                  |             |
# |    approx_kl            | 0.002921186 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.25        |
# |    n_updates            | 912         |
# |    policy_gradient_loss | 0.000317    |
# |    value_loss           | 139         |
# -----------------------------------------
# Eval num_timesteps=1900000, episode_reward=288.77 +/- 9.05
# Episode length: 237.40 +/- 15.96
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 237         |
# |    mean_reward          | 289         |
# | time/                   |             |
# |    total_timesteps      | 1900000     |
# | train/                  |             |
# |    approx_kl            | 0.004956345 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.000431   |
# |    value_loss           | 6.19        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    fps             | 844      |
# |    iterations      | 116      |
# |    time_elapsed    | 2250     |
# |    total_timesteps | 1900544  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 117         |
# |    time_elapsed         | 2267        |
# |    total_timesteps      | 1916928     |
# | train/                  |             |
# |    approx_kl            | 0.003751146 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.77        |
# |    n_updates            | 928         |
# |    policy_gradient_loss | -0.000936   |
# |    value_loss           | 43.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 846         |
# |    iterations           | 118         |
# |    time_elapsed         | 2283        |
# |    total_timesteps      | 1933312     |
# | train/                  |             |
# |    approx_kl            | 0.004066433 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67        |
# |    n_updates            | 936         |
# |    policy_gradient_loss | -0.000432   |
# |    value_loss           | 63.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 119         |
# |    time_elapsed         | 2300        |
# |    total_timesteps      | 1949696     |
# | train/                  |             |
# |    approx_kl            | 0.005042044 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83        |
# |    n_updates            | 944         |
# |    policy_gradient_loss | 0.000115    |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 120          |
# |    time_elapsed         | 2316         |
# |    total_timesteps      | 1966080      |
# | train/                  |              |
# |    approx_kl            | 0.0038670735 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 952          |
# |    policy_gradient_loss | 0.0002       |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 121          |
# |    time_elapsed         | 2334         |
# |    total_timesteps      | 1982464      |
# | train/                  |              |
# |    approx_kl            | 0.0052665225 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.3         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -6.13e-05    |
# |    value_loss           | 148          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 249        |
# |    ep_rew_mean          | 276        |
# | time/                   |            |
# |    fps                  | 850        |
# |    iterations           | 122        |
# |    time_elapsed         | 2349       |
# |    total_timesteps      | 1998848    |
# | train/                  |            |
# |    approx_kl            | 0.00437377 |
# |    clip_fraction        | 0.0576     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.651     |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.66       |
# |    n_updates            | 968        |
# |    policy_gradient_loss | -0.000174  |
# |    value_loss           | 48.4       |
# ----------------------------------------
# Eval num_timesteps=2000000, episode_reward=284.18 +/- 14.06
# Episode length: 228.00 +/- 17.74
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 228          |
# |    mean_reward          | 284          |
# | time/                   |              |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0040514823 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81         |
# |    n_updates            | 976          |
# |    policy_gradient_loss | -0.000173    |
# |    value_loss           | 76.8         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    fps             | 850      |
# |    iterations      | 123      |
# |    time_elapsed    | 2368     |
# |    total_timesteps | 2015232  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 245          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 124          |
# |    time_elapsed         | 2385         |
# |    total_timesteps      | 2031616      |
# | train/                  |              |
# |    approx_kl            | 0.0033167123 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.7         |
# |    n_updates            | 984          |
# |    policy_gradient_loss | -0.000756    |
# |    value_loss           | 141          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 125          |
# |    time_elapsed         | 2402         |
# |    total_timesteps      | 2048000      |
# | train/                  |              |
# |    approx_kl            | 0.0041083596 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.63        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 992          |
# |    policy_gradient_loss | 0.000438     |
# |    value_loss           | 73.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 126          |
# |    time_elapsed         | 2418         |
# |    total_timesteps      | 2064384      |
# | train/                  |              |
# |    approx_kl            | 0.0040022964 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.5         |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.000279    |
# |    value_loss           | 167          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 127         |
# |    time_elapsed         | 2434        |
# |    total_timesteps      | 2080768     |
# | train/                  |             |
# |    approx_kl            | 0.006365376 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.77        |
# |    n_updates            | 1008        |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 8.16        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 855          |
# |    iterations           | 128          |
# |    time_elapsed         | 2451         |
# |    total_timesteps      | 2097152      |
# | train/                  |              |
# |    approx_kl            | 0.0043366374 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 176          |
# |    n_updates            | 1016         |
# |    policy_gradient_loss | -0.00076     |
# |    value_loss           | 195          |
# ------------------------------------------
# Eval num_timesteps=2100000, episode_reward=286.39 +/- 14.59
# Episode length: 225.80 +/- 13.83
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 226          |
# |    mean_reward          | 286          |
# | time/                   |              |
# |    total_timesteps      | 2100000      |
# | train/                  |              |
# |    approx_kl            | 0.0039352365 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.22         |
# |    n_updates            | 1024         |
# |    policy_gradient_loss | -0.000751    |
# |    value_loss           | 9.81         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    fps             | 855      |
# |    iterations      | 129      |
# |    time_elapsed    | 2469     |
# |    total_timesteps | 2113536  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 130         |
# |    time_elapsed         | 2485        |
# |    total_timesteps      | 2129920     |
# | train/                  |             |
# |    approx_kl            | 0.004314499 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 1032        |
# |    policy_gradient_loss | -0.000383   |
# |    value_loss           | 3.5         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 131          |
# |    time_elapsed         | 2504         |
# |    total_timesteps      | 2146304      |
# | train/                  |              |
# |    approx_kl            | 0.0043408647 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.7          |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 33.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 132         |
# |    time_elapsed         | 2520        |
# |    total_timesteps      | 2162688     |
# | train/                  |             |
# |    approx_kl            | 0.004939926 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 1048        |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 133         |
# |    time_elapsed         | 2537        |
# |    total_timesteps      | 2179072     |
# | train/                  |             |
# |    approx_kl            | 0.003978544 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.79        |
# |    n_updates            | 1056        |
# |    policy_gradient_loss | 3.58e-05    |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 134         |
# |    time_elapsed         | 2552        |
# |    total_timesteps      | 2195456     |
# | train/                  |             |
# |    approx_kl            | 0.005709146 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66        |
# |    n_updates            | 1064        |
# |    policy_gradient_loss | 0.000478    |
# |    value_loss           | 5.97        |
# -----------------------------------------
# Eval num_timesteps=2200000, episode_reward=281.08 +/- 18.08
# Episode length: 222.80 +/- 16.63
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 223          |
# |    mean_reward          | 281          |
# | time/                   |              |
# |    total_timesteps      | 2200000      |
# | train/                  |              |
# |    approx_kl            | 0.0032505058 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 1072         |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 255          |
# ------------------------------------------
# ---------------------------------
# ...
# |    fps                  | 952          |
# |    iterations           | 290          |
# |    time_elapsed         | 4989         |
# |    total_timesteps      | 4751360      |
# | train/                  |              |
# |    approx_kl            | 0.0047536525 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.56         |
# |    n_updates            | 2312         |
# |    policy_gradient_loss | 6.6e-05      |
# |    value_loss           | 2.41         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 194          |
# |    ep_rew_mean          | 283          |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 291          |
# |    time_elapsed         | 5004         |
# |    total_timesteps      | 4767744      |
# | train/                  |              |
# |    approx_kl            | 0.0038286843 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 100          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 953          |
# |    iterations           | 292          |
# |    time_elapsed         | 5019         |
# |    total_timesteps      | 4784128      |
# | train/                  |              |
# |    approx_kl            | 0.0052898866 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65         |
# |    n_updates            | 2328         |
# |    policy_gradient_loss | -0.000405    |
# |    value_loss           | 78.6         |
# ------------------------------------------
# Eval num_timesteps=4800000, episode_reward=287.64 +/- 23.77
# Episode length: 193.90 +/- 15.33
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 194          |
# |    mean_reward          | 288          |
# | time/                   |              |
# |    total_timesteps      | 4800000      |
# | train/                  |              |
# |    approx_kl            | 0.0038449855 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 2336         |
# |    policy_gradient_loss | 0.000395     |
# |    value_loss           | 88.7         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 187      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    fps             | 953      |
# |    iterations      | 293      |
# |    time_elapsed    | 5034     |
# |    total_timesteps | 4800512  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | 288          |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 294          |
# |    time_elapsed         | 5048         |
# |    total_timesteps      | 4816896      |
# | train/                  |              |
# |    approx_kl            | 0.0047462424 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64         |
# |    n_updates            | 2344         |
# |    policy_gradient_loss | -0.0007      |
# |    value_loss           | 3.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 295          |
# |    time_elapsed         | 5063         |
# |    total_timesteps      | 4833280      |
# | train/                  |              |
# |    approx_kl            | 0.0043198997 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.45         |
# |    n_updates            | 2352         |
# |    policy_gradient_loss | -0.000751    |
# |    value_loss           | 68.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 207          |
# |    ep_rew_mean          | 279          |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 296          |
# |    time_elapsed         | 5078         |
# |    total_timesteps      | 4849664      |
# | train/                  |              |
# |    approx_kl            | 0.0039464803 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 173          |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.000815    |
# |    value_loss           | 144          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 189          |
# |    ep_rew_mean          | 289          |
# | time/                   |              |
# |    fps                  | 955          |
# |    iterations           | 297          |
# |    time_elapsed         | 5092         |
# |    total_timesteps      | 4866048      |
# | train/                  |              |
# |    approx_kl            | 0.0049482537 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.1         |
# |    n_updates            | 2368         |
# |    policy_gradient_loss | 0.000121     |
# |    value_loss           | 50.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 955          |
# |    iterations           | 298          |
# |    time_elapsed         | 5107         |
# |    total_timesteps      | 4882432      |
# | train/                  |              |
# |    approx_kl            | 0.0048221066 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.79         |
# |    n_updates            | 2376         |
# |    policy_gradient_loss | -0.000201    |
# |    value_loss           | 69.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | 288          |
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 299          |
# |    time_elapsed         | 5123         |
# |    total_timesteps      | 4898816      |
# | train/                  |              |
# |    approx_kl            | 0.0030269246 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.1         |
# |    n_updates            | 2384         |
# |    policy_gradient_loss | -0.000576    |
# |    value_loss           | 286          |
# ------------------------------------------
# Eval num_timesteps=4900000, episode_reward=288.74 +/- 21.74
# Episode length: 194.30 +/- 15.36
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 194         |
# |    mean_reward          | 289         |
# | time/                   |             |
# |    total_timesteps      | 4900000     |
# | train/                  |             |
# |    approx_kl            | 0.005267947 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91        |
# |    n_updates            | 2392        |
# |    policy_gradient_loss | -0.000152   |
# |    value_loss           | 78.4        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    fps             | 956      |
# |    iterations      | 300      |
# |    time_elapsed    | 5138     |
# |    total_timesteps | 4915200  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 285         |
# | time/                   |             |
# |    fps                  | 956         |
# |    iterations           | 301         |
# |    time_elapsed         | 5153        |
# |    total_timesteps      | 4931584     |
# | train/                  |             |
# |    approx_kl            | 0.005215802 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.4        |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | 9.44e-05    |
# |    value_loss           | 52.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 188          |
# |    ep_rew_mean          | 289          |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 302          |
# |    time_elapsed         | 5168         |
# |    total_timesteps      | 4947968      |
# | train/                  |              |
# |    approx_kl            | 0.0035034607 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.451       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.844        |
# |    n_updates            | 2408         |
# |    policy_gradient_loss | 0.000501     |
# |    value_loss           | 72.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | 286          |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 303          |
# |    time_elapsed         | 5182         |
# |    total_timesteps      | 4964352      |
# | train/                  |              |
# |    approx_kl            | 0.0029883874 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.12         |
# |    n_updates            | 2416         |
# |    policy_gradient_loss | 0.000194     |
# |    value_loss           | 73.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 304          |
# |    time_elapsed         | 5196         |
# |    total_timesteps      | 4980736      |
# | train/                  |              |
# |    approx_kl            | 0.0058655455 |
# |    clip_fraction        | 0.0611       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04         |
# |    n_updates            | 2424         |
# |    policy_gradient_loss | 0.000211     |
# |    value_loss           | 59.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 281         |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 305         |
# |    time_elapsed         | 5211        |
# |    total_timesteps      | 4997120     |
# | train/                  |             |
# |    approx_kl            | 0.004203885 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 484         |
# |    n_updates            | 2432        |
# |    policy_gradient_loss | -0.000958   |
# |    value_loss           | 224         |
# -----------------------------------------
# Eval num_timesteps=5000000, episode_reward=284.61 +/- 15.92
# Episode length: 189.00 +/- 20.64
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 189          |
# |    mean_reward          | 285          |
# | time/                   |              |
# |    total_timesteps      | 5000000      |
# | train/                  |              |
# |    approx_kl            | 0.0059749107 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | 0.000285     |
# |    value_loss           | 121          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | 284      |
# | time/              |          |
# |    fps             | 959      |
# |    iterations      | 306      |
# |    time_elapsed    | 5226     |
# |    total_timesteps | 5013504  |
# ---------------------------------

# %% [markdown]
# ### Evaluate the model

# %%
# Create a new environment for evaluation
eval_env = gym.make('LunarLander-v2')

# Evaluate the model with 10 evaluation episodes and deterministic
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes = 10, deterministic = True) 

#Print the results
print("Mean reward %0.2f, Std reward %0.2f" % (mean_reward, std_reward))
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward 288.08, Std reward 35.44

# %% [markdown]
# ### Publish the thrained model to the hub

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
# !ls
# Out:
# rl-baselines3-zoo  sample_data

# %%
model = PPO.load("/content/rl-baselines3-zoo/logs/best_model.zip")

# %%
# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name="ppo-LunarLander-v2", # The name of our trained model 
               model_architecture="PPO", # The model architecture we used: in our case PPO
               env_id="LunarLander-v2", # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id="LuniLand/ppo-LunarLander-v2", # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message="Push to Hub")
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpjx48o1ze/-step-0-to-step-1000.mp4
# ℹ Pushing repo LuniLand/ppo-LunarLander-v2 to the Hugging Face Hub
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/LuniLand/ppo-LunarLander-v2/tree/main/
# 'https://huggingface.co/LuniLand/ppo-LunarLander-v2/tree/main/'

# %% [markdown]
# ### Load a trained model

# %%
repo_id = "ThomasSimonini/ppo-LunarLander-v2"
filename = "ppo-LunarLander-v2.zip"
custom_objects = {
    "learning_rate": lambda _: 0.0,
    "lr_schedule": lambda _: 0.0,
    "clip_range": lambda _: 0.0
}
checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects = custom_objects, print_system_info = True)

# %% [markdown]
# evalute this model

# %%
eval_env = gym.make('LunarLander-v2')
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic = True)
print(f"mean reward {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean reward 261.28 +/- 21.97

# %% [markdown]
# watch the agent in action

# %%
from stable_baselines3.common.vec_env import VecFrameStack
from colabgymrender.recorder import Recorder


env = make_vec_env('LunarLander-v2', n_envs=1)
env = VecFrameStack(env, n_stack = 1)

directory = './video'
env = Recorder(env, directory)

obs = env.reset()
done = False
while not done:
  action, _state = model.predict(obs)
  obs, reward, done, info = env.step(action)
env.play()

# %% [markdown]
# # DQN

# %%
from stable_baselines3 import DQN

env = make_vec_env('LunarLander-v2', n_envs = 16)

model = DQN('MlpPolicy', env, verbose = 1, exploration_final_eps=0.1, target_update_interval=250)

model.learn(total_timesteps = int(1e5), progress_bar = True)
model_name = "dqn-LunarLander-v2"
model.save(model_name)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.8/dist-packages/stable_baselines3/common/callbacks.py:680: TqdmExperimentalWarning: rich is experimental/alpha
#   self.pbar = tqdm(total=self.locals["total_timesteps"] - self.model.num_timesteps)
# Output()
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 687      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -218     |
# |    exploration_rate | 0.103    |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 3262     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 94464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.83     |
# |    n_updates        | 694      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 3258     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 94688    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 698      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.0932   |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 3247     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 95456    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.983    |
# |    n_updates        | 710      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.09     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 3244     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 95792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.31     |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.088    |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 3240     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 96000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84     |
# |    n_updates        | 718      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.0783   |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 3234     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 97024    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 734      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.0745   |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 3229     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 97424    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 741      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.0663   |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 3221     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 98288    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.78     |
# |    n_updates        | 754      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.064    |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 3218     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 98528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 758      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.0591   |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 3212     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 99040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 766      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.0505   |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 3197     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 99952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.8      |
# |    n_updates        | 780      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 3193     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 100064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.07     |
# |    n_updates        | 782      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 3190     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 100528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.45     |
# |    n_updates        | 789      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 3187     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 100960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 796      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 3181     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 101552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 805      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 3179     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 101792   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 809      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 3177     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 102064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 813      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 3167     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 103120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.26     |
# |    n_updates        | 830      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 3164     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 103408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.71     |
# |    n_updates        | 834      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 3161     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 103648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.972    |
# |    n_updates        | 838      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 3150     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 104672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.97     |
# |    n_updates        | 854      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 3096     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 105824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.36     |
# |    n_updates        | 872      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 3089     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 106304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 879      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 3077     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 107120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09     |
# |    n_updates        | 892      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 3057     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 108048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 907      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 3052     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 108368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 912      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 3050     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 108624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.74     |
# |    n_updates        | 916      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 3044     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 109504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.06     |
# |    n_updates        | 929      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 3030     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 110736   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.92     |
# |    n_updates        | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 3025     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 111152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 955      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 3013     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 112304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 973      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 3009     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 112592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.65     |
# |    n_updates        | 978      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 3007     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 112848   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.686    |
# |    n_updates        | 982      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 2998     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 114064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 1001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 2994     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 114736   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 1011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 2987     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 115264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.68     |
# |    n_updates        | 1019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 2980     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 116048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 1032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 2966     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 117216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.02     |
# |    n_updates        | 1050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 2960     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 117568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 1055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 2953     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 118128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.12     |
# |    n_updates        | 1064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -210     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 2943     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 119248   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 1082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | -213     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 2933     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 120000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.03     |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | -218     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 2893     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 121184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 2866     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 122064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 1126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 2792     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 123776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -235     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 2711     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 125600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -243     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 2650     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 126720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.07     |
# |    n_updates        | 1198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | -245     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 2565     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 128224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.871    |
# |    n_updates        | 1222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -253     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 2428     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 129920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 1248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -252     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 2212     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 133568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 1305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | -248     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 2181     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 134448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55     |
# |    n_updates        | 1319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | -248     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 2141     |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 136000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.32     |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | -257     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 2112     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 137232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 1363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 246      |
# |    ep_rew_mean      | -270     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 2052     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 139760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.67     |
# |    n_updates        | 1402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 249      |
# |    ep_rew_mean      | -270     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 2025     |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 140720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 1417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 255      |
# |    ep_rew_mean      | -274     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 1990     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 142016   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 1437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | -282     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 1975     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 142704   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 1448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | -276     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 1973     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 143312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21     |
# |    n_updates        | 1458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -276     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 1972     |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 144000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12     |
# |    n_updates        | 1468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -275     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 1973     |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 144512   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.891    |
# |    n_updates        | 1476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -279     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 1974     |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 145312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 1489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -272     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 1972     |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 146864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 1513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -268     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 1969     |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 147776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 1527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -266     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 1967     |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 148384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.38     |
# |    n_updates        | 1537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -265     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 1957     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 150624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 1572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 305      |
# |    ep_rew_mean      | -262     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 1951     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 151472   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 1585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | -263     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 1945     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 152432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 315      |
# |    ep_rew_mean      | -256     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 1936     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 153856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.848    |
# |    n_updates        | 1622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 321      |
# |    ep_rew_mean      | -260     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 1926     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 155824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.66     |
# |    n_updates        | 1653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | -249     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 1914     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 157232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 1675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 328      |
# |    ep_rew_mean      | -248     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 1889     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 159808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4      |
# |    n_updates        | 1715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 334      |
# |    ep_rew_mean      | -245     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 1874     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 160704   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 1729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 346      |
# |    ep_rew_mean      | -239     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 1854     |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 162112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 1751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | -239     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 1828     |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 164368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 1787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 347      |
# |    ep_rew_mean      | -247     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 1821     |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 165424   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 1803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 326      |
# |    ep_rew_mean      | -243     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 1798     |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 167808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.05     |
# |    n_updates        | 1840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 328      |
# |    ep_rew_mean      | -242     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 1733     |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 171456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.92     |
# |    n_updates        | 1897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -234     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 1661     |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 174496   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 1945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | -228     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 1605     |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 176592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 1978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 376      |
# |    ep_rew_mean      | -216     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 1562     |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 178720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.86     |
# |    n_updates        | 2011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 397      |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 1508     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 182288   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.01     |
# |    n_updates        | 2067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 393      |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 1462     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 185184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.1      |
# |    n_updates        | 2112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 395      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 1404     |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 188480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 2163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 1340     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 191808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 2215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 440      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 1322     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 193680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 2245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 1295     |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 196640   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.4      |
# |    n_updates        | 2291     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 1250     |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 201184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 2362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 508      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 1227     |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 203584   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 2399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 530      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 1184     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 207808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 2465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 557      |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 1169     |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 209680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 2495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 573      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1296     |
# ...
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -46.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 620      |
# |    time_elapsed     | 1418     |
# |    total_timesteps  | 880784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.547    |
# |    n_updates        | 12981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -46.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 620      |
# |    time_elapsed     | 1427     |
# |    total_timesteps  | 885008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.739    |
# |    n_updates        | 13047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -45      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 619      |
# |    time_elapsed     | 1430     |
# |    total_timesteps  | 886960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.679    |
# |    n_updates        | 13077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -44.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 617      |
# |    time_elapsed     | 1448     |
# |    total_timesteps  | 894528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.834    |
# |    n_updates        | 13195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -43.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 616      |
# |    time_elapsed     | 1454     |
# |    total_timesteps  | 896784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.871    |
# |    n_updates        | 13231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -42.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 614      |
# |    time_elapsed     | 1465     |
# |    total_timesteps  | 901008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.798    |
# |    n_updates        | 13297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -43      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 614      |
# |    time_elapsed     | 1470     |
# |    total_timesteps  | 902960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.645    |
# |    n_updates        | 13327    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -42.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 612      |
# |    time_elapsed     | 1485     |
# |    total_timesteps  | 910528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.632    |
# |    n_updates        | 13445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -41.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 612      |
# |    time_elapsed     | 1490     |
# |    total_timesteps  | 912784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.85     |
# |    n_updates        | 13481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -40.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 611      |
# |    time_elapsed     | 1500     |
# |    total_timesteps  | 917008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.737    |
# |    n_updates        | 13547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -40.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 610      |
# |    time_elapsed     | 1504     |
# |    total_timesteps  | 918960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.94     |
# |    n_updates        | 13577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -42.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 609      |
# |    time_elapsed     | 1519     |
# |    total_timesteps  | 926528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.801    |
# |    n_updates        | 13695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -42.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 609      |
# |    time_elapsed     | 1524     |
# |    total_timesteps  | 928784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.506    |
# |    n_updates        | 13731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -41.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 609      |
# |    time_elapsed     | 1531     |
# |    total_timesteps  | 933008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.709    |
# |    n_updates        | 13797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -41      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 609      |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 934960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05     |
# |    n_updates        | 13827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -40.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 608      |
# |    time_elapsed     | 1553     |
# |    total_timesteps  | 944784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.814    |
# |    n_updates        | 13981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -38.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 608      |
# |    time_elapsed     | 1560     |
# |    total_timesteps  | 949008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 14047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -39.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 607      |
# |    time_elapsed     | 1564     |
# |    total_timesteps  | 950960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 14077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -39.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 606      |
# |    time_elapsed     | 1579     |
# |    total_timesteps  | 958528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.881    |
# |    n_updates        | 14195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -37.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 606      |
# |    time_elapsed     | 1584     |
# |    total_timesteps  | 960784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22     |
# |    n_updates        | 14231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -38      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 605      |
# |    time_elapsed     | 1593     |
# |    total_timesteps  | 965008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.631    |
# |    n_updates        | 14297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -37      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 605      |
# |    time_elapsed     | 1596     |
# |    total_timesteps  | 966960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.857    |
# |    n_updates        | 14327    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -36.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 604      |
# |    time_elapsed     | 1611     |
# |    total_timesteps  | 974528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.953    |
# |    n_updates        | 14445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -35.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 604      |
# |    time_elapsed     | 1616     |
# |    total_timesteps  | 976784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.889    |
# |    n_updates        | 14481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -34.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 603      |
# |    time_elapsed     | 1624     |
# |    total_timesteps  | 981008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.934    |
# |    n_updates        | 14547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -32.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 603      |
# |    time_elapsed     | 1628     |
# |    total_timesteps  | 982960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.907    |
# |    n_updates        | 14577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -32.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 603      |
# |    time_elapsed     | 1642     |
# |    total_timesteps  | 990528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.774    |
# |    n_updates        | 14695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -32      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 602      |
# |    time_elapsed     | 1646     |
# |    total_timesteps  | 992784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.73     |
# |    n_updates        | 14731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -31.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2276     |
# |    fps              | 602      |
# |    time_elapsed     | 1655     |
# |    total_timesteps  | 997008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.894    |
# |    n_updates        | 14797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | -30.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2280     |
# |    fps              | 602      |
# |    time_elapsed     | 1659     |
# |    total_timesteps  | 998960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.484    |
# |    n_updates        | 14827    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
eval_env = gym.make('LunarLander-v2')

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, deterministic = True)

print(f"mean reward {mean_reward:.2f} +/- {std_reward:.2f}")

# %% [markdown]
# DQN RL ZOO Optimized

# %%
# !pip install rl_zoo3

# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo

# %%
# %cd rl-baselines3-zoo/

# %%
# !python train.py --algo dqn --env LunarLander-v2 --eval-episodes 10 --eval-freq 10000

# %%
# !python enjoy.py --algo dqn --env LunarLander-v2 -f logs/ --exp-id 0

# %%
notebook_login()

# %%
# !python -m rl_zoo3.push_to_hub --algo dqn --env LunarLander-v2 -f logs/ -orga LuniLand -m "Upload LunarLander-v2 optimized" --repo-name dqn-LunarLander-v2
